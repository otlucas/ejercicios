# %%
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format

# %%
users = pd.DataFrame()

# %%
from random import randrange
from datetime import timedelta

def random_date(start, end):
    """
    This function will return a random datetime between two datetime 
    objects.
    """
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    return start + timedelta(seconds=random_second)

# %%
import random as random
import string as string
import numpy as np
usersRows = []
nicknameList = []
i = 0
d1 = pd.to_datetime('1/1/2008 1:30 PM', format='%m/%d/%Y %I:%M %p')
d2 = pd.to_datetime('1/1/2009 4:50 AM', format='%m/%d/%Y %I:%M %p')
while i < 1000:
    nickname = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(6))
    country = ""
    if(i % 2 == 0):
        country = "CO"
    elif (i % 3 == 0):
        country = "PA"
    else:
        country = "AR"
    seguidores = np.random.randint(0, 100000000)
    seguidos = seguidores * np.random.randint(0, 3000) / np.random.randint(1, 1000)
    cantidadPublis = np.random.randint(0, 1500)
    usersRows.append((i, nickname, country, random_date(d1, d2), seguidores, seguidos, cantidadPublis))
    nicknameList.append(nickname)
    i = i + 1;
users = pd.DataFrame(usersRows, columns = ['id_usuario' , 'nickname', 'pais' , 'date', 'cantidad_seguidores', 'cantidad_seguidos', 'cantidad_total_publicaciones'])

# %%
users
# Out:
#      id_usuario nickname pais                date  cantidad_seguidores  \
# 0             0   MFGO5V   CO 2008-12-31 15:37:37             15807750
# 1             1   NV2YWN   AR 2008-09-24 21:46:49             59453501
# 2             2   B4S0HS   CO 2008-11-29 09:09:24             17836129
# 3             3   Q5R2NS   PA 2008-10-16 12:32:11             75663083
# 4             4   KJQSHJ   CO 2008-10-04 07:36:23             60165058
# 5             5   9QNJS8   AR 2008-11-09 01:41:51             19849112
# 6             6   2WZL8W   CO 2008-07-09 13:14:38             80176877
# 7             7   YF02IR   AR 2008-11-08 20:30:05             31262354
# 8             8   BQWCFM   CO 2008-07-04 16:22:34             95795882
# 9             9   ZE6JKJ   PA 2008-05-18 22:54:12             93174003
# 10           10   78IP3J   CO 2008-06-08 17:38:52             71034544
# 11           11   6MXDR3   AR 2008-09-10 20:59:15             49229494
# ...

# %%
users.sort_values(by="cantidad_seguidores", ascending=False).head(10)
# Out:
#      id_usuario nickname pais                date  cantidad_seguidores  \
# 284         284   Z65C2A   CO 2008-07-06 22:46:02             99969569
# 338         338   UGI3HR   CO 2008-12-30 13:54:30             99872846
# 749         749   RR8GGR   AR 2008-05-27 14:17:09             99844703
# 632         632   4A2TTC   CO 2008-07-06 10:23:39             99474585
# 233         233   5J48XJ   AR 2008-10-01 17:07:08             99412548
# 179         179   N571LB   AR 2008-09-04 08:37:12             98923023
# 771         771   I2ICEP   PA 2008-12-25 02:07:14             98876212
# 925         925   DG3A2P   AR 2008-01-27 05:10:44             98842268
# 763         763   ZTL0Z1   AR 2008-04-15 13:09:53             98770612
# 381         381   77LT2R   PA 2008-07-11 19:23:31             98706747
#
#      cantidad_seguidos  cantidad_total_publicaciones
# 284       465478401.34                          1148
# 338      1154627536.68                           123
# ...

# %%
users["cantidad_seguidores"].max()*80/100
# Out:
# 79975655.2

# %%
users[((users.cantidad_seguidores * 15/100) >= users.cantidad_seguidos) & (users.cantidad_seguidores >= users["cantidad_seguidores"].max()*60/100)].sort_values(by="cantidad_seguidores", ascending=False).head(10)
# Out:
#      id_usuario nickname pais                date  cantidad_seguidores  \
# 972         972   4R7MHX   CO 2008-10-06 00:51:35             98369362
# 568         568   U0DZU5   CO 2008-08-17 09:34:55             84510841
# 466         466   D5JKAD   CO 2008-12-08 04:15:00             80470859
# 508         508   CFJTMX   CO 2008-07-28 16:10:15             77085135
# 619         619   B5AITO   AR 2008-06-01 03:11:40             76931542
# 847         847   Y281MZ   AR 2008-10-12 20:53:09             73136059
# 525         525   QMFHTF   PA 2008-02-24 05:17:54             65062996
# 711         711   WNTO51   PA 2008-03-28 02:28:43             61858255
# 290         290   KN2JAD   CO 2008-06-10 18:07:18             60658279
#
#      cantidad_seguidos  cantidad_total_publicaciones
# 972         4183647.89                           139
# 568         5683477.61                           485
# 466         5647077.82                           855
# ...
