# %%
import pandas as pd
import datetime as dt
scrubbed = pd.read_csv('scrubbed.csv')
complete = pd.read_csv('complete.csv', error_bad_lines=False)
scrubbed["duration (seconds)"] = pd.to_numeric(scrubbed["duration (seconds)"], errors='coerce')
complete["duration (seconds)"] = pd.to_numeric(complete["duration (seconds)"], errors='coerce')
# Out:
# /home/lucas/.conda/envs/asd/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
#COMPLETE
#datetimeContains date and time of sighting
#cityCity in which UFO was sighted
#stateState in which UFO was sighted
#countryCountry of Sighting
#shapeShape of the UFO
#duration (seconds)Duration of the Sighting in seconds
#duration (hours/min)Duration of the sighting in hours and min
#commentsSighting description
#date postedPosted date of the sighting
#latitudeLatitude coordinate of the sighting
#longitudeLongitude coordinate of the sighting
complete
# Out:
#                datetime                                   city state country  \
# 0      10/10/1949 20:30                             san marcos    tx      us
# 1      10/10/1949 21:00                           lackland afb    tx     NaN
# 2      10/10/1955 17:00                   chester (uk/england)   NaN      gb
# 3      10/10/1956 21:00                                   edna    tx      us
# 4      10/10/1960 20:00                                kaneohe    hi      us
# 5      10/10/1961 19:00                                bristol    tn      us
# 6      10/10/1965 21:00                     penarth (uk/wales)   NaN      gb
# 7      10/10/1965 23:45                                norwalk    ct      us
# 8      10/10/1966 20:00                              pell city    al      us
# 9      10/10/1966 21:00                               live oak    fl      us
# 10     10/10/1968 13:00                              hawthorne    ca      us
# ...

# %%
#SCRUBBED
#datetime
#city
#state
#country
#shape
#duration (seconds)
#duration (hours/min)
#comments
#date posted
#latitude
#longitude
scrubbed
# Out:
#                datetime                                   city state country  \
# 0      10/10/1949 20:30                             san marcos    tx      us
# 1      10/10/1949 21:00                           lackland afb    tx     NaN
# 2      10/10/1955 17:00                   chester (uk/england)   NaN      gb
# 3      10/10/1956 21:00                                   edna    tx      us
# 4      10/10/1960 20:00                                kaneohe    hi      us
# 5      10/10/1961 19:00                                bristol    tn      us
# 6      10/10/1965 21:00                     penarth (uk/wales)   NaN      gb
# 7      10/10/1965 23:45                                norwalk    ct      us
# 8      10/10/1966 20:00                              pell city    al      us
# 9      10/10/1966 21:00                               live oak    fl      us
# 10     10/10/1968 13:00                              hawthorne    ca      us
# ...

# %%
countShapesComplete = complete.groupby("shape")["shape"].agg({"count"}).reset_index()
countShapesComplete[countShapesComplete["shape"] == "diamond"]["count"]
# Out:
# 10    1308
# Name: count, dtype: int64

# %%
countShapesComplete[countShapesComplete["shape"] == "cross"]["count"]
# Out:
# 7    265
# Name: count, dtype: int64

# %%
countShapesScrubbed = scrubbed.groupby("shape")["shape"].agg({"count"}).reset_index()
countShapesScrubbed[countShapesScrubbed["shape"] == "diamond"]["count"]
# Out:
# 10    1178
# Name: count, dtype: int64

# %%
countShapesScrubbed[countShapesScrubbed["shape"] == "cross"]["count"]
# Out:
# 7    233
# Name: count, dtype: int64

# %%
countShapesScrubbed[countShapesScrubbed["shape"] == "chevron"]["count"]
# Out:
# 2    952
# Name: count, dtype: int64

# %%
countShapesComplete[countShapesComplete["shape"] == "chevron"]["count"]
# Out:
# 2    1007
# Name: count, dtype: int64

# %%
complete[complete["datetime"].str.contains("2010")][complete["country"] == "ca"].agg({"count"})["datetime"]
# Out:
# /home/lucas/.conda/envs/asd/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# count    154
# Name: datetime, dtype: int64

# %%
scrubbed[scrubbed["datetime"].str.contains("2010")][complete["country"] == "ca"].agg({"count"})["datetime"]
# Out:
# /home/lucas/.conda/envs/asd/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# count    152
# Name: datetime, dtype: int64

# %%
complete['datetime'] = complete['datetime'].map(lambda x : x[:-5])
complete['datetime'] =pd.to_datetime(complete.datetime)
complete[complete["shape"] == "light"].sort_values("datetime", ascending=False)
# Out:
#         datetime                            city state country  shape  \
# 51245 2014-05-08           inverloch (australia)   NaN      au  light
# 50899 2014-05-06                        hernando    ms      us  light
# 50900 2014-05-06                          oxford    mi      us  light
# 50903 2014-05-06                      ellensburg    wa      us  light
# 50733 2014-05-05                   coral springs    fl      us  light
# 50732 2014-05-05                      st. helens   NaN     NaN  light
# 50477 2014-05-04                        rockford    tn      us  light
# 50284 2014-05-03                   waikiki beach    hi     NaN  light
# 50299 2014-05-03                     thomasville    nc      us  light
# 50294 2014-05-03                     parkersburg    wv      us  light
# 50290 2014-05-03                         hialeah    fl      us  light
# 50288 2014-05-03                          currie    nc      us  light
# ...

# %%
scrubbed[scrubbed["duration (seconds)"].notnull()].sort_values("duration (seconds)")
# Out:
#                datetime                              city state country  \
# 4081   10/23/2008 04:45                            remote    wy     NaN
# 70587   8/30/2002 13:45       kerry (republic of ireland)   NaN     NaN
# 42378   5/15/1987 23:00                       island lake    il      us
# 70393   8/29/2002 23:45                            toledo    or      us
# 52996   6/30/2002 03:15                helsinki (finland)   NaN     NaN
# 23754   12/9/1999 18:15                              lyle    wa      us
# 56596   7/15/1974 22:00                        bridgeview    il      us
# 13375  11/28/2001 03:41                         milwaukie    or      us
# 67354   8/17/2013 24:00               abbotsford (canada)    bc      ca
# 42057   5/13/2003 22:00                             grove    oh     NaN
# 18735  12/17/2011 18:40                        springhill    fl     NaN
# 2038   10/15/2001 20:22                      port orchard    wa      us
# ...

# %%
countShapesComplete
# Out:
#         shape  count
# 0     changed      1
# 1    changing   2140
# 2     chevron   1007
# 3       cigar   2241
# 4      circle   8453
# 5        cone    367
# 6    crescent      2
# 7       cross    265
# 8    cylinder   1382
# 9       delta      8
# 10    diamond   1308
# 11       disk   6005
# 12       dome      1
# 13        egg    845
# 14   fireball   6562
# 15      flare      1
# 16      flash   1472
# 17  formation   2657
# 18    hexagon      1
# 19      light  17872
# 20      other   6247
# 21       oval   4119
# 22    pyramid      1
# 23  rectangle   1418
# 24      round      2
# 25     sphere   5755
# 26   teardrop    817
# 27   triangle   8489
# 28    unknown   6319

# %%
countShapesScrubbed
# Out:
#         shape  count
# 0     changed      1
# 1    changing   1962
# 2     chevron    952
# 3       cigar   2057
# 4      circle   7608
# 5        cone    316
# 6    crescent      2
# 7       cross    233
# 8    cylinder   1283
# 9       delta      7
# 10    diamond   1178
# 11       disk   5213
# 12       dome      1
# 13        egg    759
# 14   fireball   6208
# 15      flare      1
# 16      flash   1328
# 17  formation   2457
# 18    hexagon      1
# 19      light  16565
# 20      other   5649
# 21       oval   3733
# 22    pyramid      1
# 23  rectangle   1297
# 24      round      2
# 25     sphere   5387
# 26   teardrop    750
# 27   triangle   7865
# 28    unknown   5584

# %%
complete.groupby("shape").agg({"duration (seconds)": "mean"}).reset_index().sort_values("duration (seconds)")
# Out:
#         shape  duration (seconds)
# 12       dome            2.000000
# 15      flare           30.000000
# 22    pyramid          120.000000
# 18    hexagon          240.000000
# 24      round          452.500000
# 2     chevron          488.626564
# 23  rectangle          642.585603
# 7       cross          658.358491
# 26   teardrop          869.313953
# 17  formation         1183.579925
# 27   triangle         1579.568643
# 13        egg         1704.036805
# 3       cigar         1805.303414
# 1    changing         1933.579579
# 11       disk         2018.303386
# 9       delta         2019.375000
# 8    cylinder         3184.079233
# 21       oval         3549.204346
# 0     changed         3600.000000
# 14   fireball         3830.850386
# 4      circle         4307.613263
# 16      flash         4818.921434
# 28    unknown         4919.787990
# 10    diamond         6114.575321
# 19      light        12256.439415
# 20      other        18669.292910
# ...
